# %% [markdown]
# # 1. Define goal
# Create a model that predicts bike sharing demand; optimize for RMSLE.

# %% [markdown]
# # 2. Get data

# %%
# import packages
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set() 
sns.set_style("darkgrid")

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# **Data Fields**
#
# **datetime** - hourly date + timestamp\
# **season** -  1 = spring, 2 = summer, 3 = fall, 4 = winter\
# **holiday** - whether the day is considered a holiday\
# **workingday** - whether the day is neither a weekend nor holiday\
# "Working Day" (workingday=1, holiday=0),\
# "Holiday" (workingday=0, holiday=1), and\
# "Weekend" (workingday=0, holiday=0).\
# Presumably there is no case where workingday=1 and holiday=1?
#
#
# **weather** -
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy \
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# **temp** - temperature in Celsius\
# **atemp** - "feels like" temperature in Celsius\
# **humidity** - relative humidity\
# **windspeed** - wind speed\
# **casual** - number of non-registered user rentals initiated\
# **registered** - number of registered user rentals initiated\
# **count** - number of total rentals

# %%
df.shape
# Out:
# (10886, 12)

# %%
# extract year, month and hour from datetime into new columns
# inspired by: https://stackoverflow.com/questions/25146121/extracting-just-month-and-year-separately-from-pandas-datetime-column
df['year'] = pd.DatetimeIndex(df['datetime']).year
df['month'] = pd.DatetimeIndex(df['datetime']).month
df['hour'] = pd.DatetimeIndex(df['datetime']).hour
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  hour
# 0        81        0.0       3          13     16  2011      1     0
# 1        80        0.0       8          32     40  2011      1     1
# 2        80        0.0       5          27     32  2011      1     2
# 3        75        0.0       3          10     13  2011      1     3
# 4        75        0.0       0           1      1  2011      1     4

# %%
# set datetime as index
df.set_index(pd.to_datetime(df['datetime']), inplace= True)
df.head()
# Out:
#                                 datetime  season  holiday  workingday  \
# datetime
# 2011-01-01 00:00:00  2011-01-01 00:00:00       1        0           0
# 2011-01-01 01:00:00  2011-01-01 01:00:00       1        0           0
# 2011-01-01 02:00:00  2011-01-01 02:00:00       1        0           0
# 2011-01-01 03:00:00  2011-01-01 03:00:00       1        0           0
# 2011-01-01 04:00:00  2011-01-01 04:00:00       1        0           0
#
#                      weather  temp   atemp  humidity  windspeed  casual  \
# datetime
# 2011-01-01 00:00:00        1  9.84  14.395        81        0.0       3
# 2011-01-01 01:00:00        1  9.02  13.635        80        0.0       8
# 2011-01-01 02:00:00        1  9.02  13.635        80        0.0       5
# 2011-01-01 03:00:00        1  9.84  14.395        75        0.0       3
# 2011-01-01 04:00:00        1  9.84  14.395        75        0.0       0
#
#                      registered  count  year  month  hour
# datetime
# 2011-01-01 00:00:00          13     16  2011      1     0
# 2011-01-01 01:00:00          32     40  2011      1     1
# 2011-01-01 02:00:00          27     32  2011      1     2
# 2011-01-01 03:00:00          10     13  2011      1     3
# 2011-01-01 04:00:00           1      1  2011      1     4

# %%
# remove unnecessary column
df.drop(['datetime'], axis = 1, inplace= True)
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16  2011
# 2011-01-01 01:00:00        80        0.0       8          32     40  2011
# 2011-01-01 02:00:00        80        0.0       5          27     32  2011
# 2011-01-01 03:00:00        75        0.0       3          10     13  2011
# 2011-01-01 04:00:00        75        0.0       0           1      1  2011
#
#                      month  hour
# datetime
# 2011-01-01 00:00:00      1     0
# 2011-01-01 01:00:00      1     1
# 2011-01-01 02:00:00      1     2
# 2011-01-01 03:00:00      1     3
# 2011-01-01 04:00:00      1     4

# %%
df['hour_bins']=pd.cut(df['hour'], bins=[-1,6,9,15,19,23], labels =['night','morgning-rush','midday-low','afterwork-rush','evening-low'])
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16  2011
# 2011-01-01 01:00:00        80        0.0       8          32     40  2011
# 2011-01-01 02:00:00        80        0.0       5          27     32  2011
# 2011-01-01 03:00:00        75        0.0       3          10     13  2011
# 2011-01-01 04:00:00        75        0.0       0           1      1  2011
#
#                      month  hour hour_bins
# datetime
# 2011-01-01 00:00:00      1     0     night
# 2011-01-01 01:00:00      1     1     night
# 2011-01-01 02:00:00      1     2     night
# 2011-01-01 03:00:00      1     3     night
# 2011-01-01 04:00:00      1     4     night

# %%
df['hour_bins'].unique()
# Out:
# ['night', 'morgning-rush', 'midday-low', 'afterwork-rush', 'evening-low']
# Categories (5, object): ['night' < 'morgning-rush' < 'midday-low' < 'afterwork-rush' < 'evening-low']

# %% [markdown]
# # 3. Train-test-split

# %%
# Define Variable of interest
X = df[['workingday', 'atemp', 'year', 'month', 'hour', 'humidity', 'weather', 'season']]
y = df['count']
X.head()
# Out:
#                      workingday   atemp  year  month  hour  humidity  weather  \
# datetime
# 2011-01-01 00:00:00           0  14.395  2011      1     0        81        1
# 2011-01-01 01:00:00           0  13.635  2011      1     1        80        1
# 2011-01-01 02:00:00           0  13.635  2011      1     2        80        1
# 2011-01-01 03:00:00           0  14.395  2011      1     3        75        1
# 2011-01-01 04:00:00           0  14.395  2011      1     4        75        1
#
#                      season
# datetime
# 2011-01-01 00:00:00       1
# 2011-01-01 01:00:00       1
# 2011-01-01 02:00:00       1
# 2011-01-01 03:00:00       1
# 2011-01-01 04:00:00       1

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=101)
X_train.shape, X_test.shape
# Out:
# ((8708, 8), (2178, 8))

# %% [markdown]
# # 4. Explore data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10886 entries, 2011-01-01 00:00:00 to 2012-12-19 23:00:00
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  int64
#  1   holiday     10886 non-null  int64
#  2   workingday  10886 non-null  int64
#  3   weather     10886 non-null  int64
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   casual      10886 non-null  int64
#  9   registered  10886 non-null  int64
#  10  count       10886 non-null  int64
#  11  year        10886 non-null  int64
#  12  month       10886 non-null  int64
#  13  hour        10886 non-null  int64
# dtypes: float64(3), int64(11)
# memory usage: 1.5 MB

# %%
df['workingday'].unique()
# Out:
# array([0, 1])

# %%
df['holiday'].unique()
# Out:
# array([0, 1])

# %%
# there are no workingdays which are also holidays
len(df[(df['workingday'] == 1) & (df['holiday'] == 1)])
# Out:
# 0

# %%
# number of workingdays (Mo-Fr)
len(df[(df['workingday'] == 1) & (df['holiday'] == 0)])
# Out:
# 7412

# %%
# number of holidays
len(df[(df['workingday'] == 0) & (df['holiday'] == 1)])
# Out:
# 311

# %%
# number of weekenddays which are not a holiday
len(df[(df['workingday'] == 0) & (df['holiday'] == 0)])
# Out:
# 3163

# %%
df['season'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df.groupby(['month'])['count'].agg(['mean'])
# Out:
#              mean
# month
# 1       90.366516
# 2      110.003330
# 3      148.169811
# 4      184.160616
# 5      219.459430
# 6      242.031798
# 7      235.325658
# 8      234.118421
# 9      233.805281
# 10     227.699232
# 11     193.677278
# 12     175.614035

# %%
df.groupby(['weather', 'workingday'])['count'].agg(['mean'])
# Out:
#                           mean
# weather workingday
# 1       0           203.345941
#         1           206.156231
# 2       0           166.529543
#         1           184.709861
# 3       0           120.633929
#         1           118.215748
# 4       1           164.000000

# %%
df.groupby(['weather', 'workingday'])['registered', 'casual'].agg(['mean']).unstack(1)
# Out:
# /var/folders/zs/dkf6mjq97k926d6m48gdwfs00000gn/T/ipykernel_39093/3653141842.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['weather', 'workingday'])['registered', 'casual'].agg(['mean']).unstack(1)
#             registered                 casual
#                   mean                   mean
# workingday           0           1          0          1
# weather
# 1           137.805780  178.116553  65.540161  28.039678
# 2           117.221851  162.501807  49.307692  22.208054
# 3            86.741071  106.576378  33.892857  11.639370
# 4                  NaN  158.000000        NaN   6.000000

# %%
df.groupby(['weather', 'workingday'])['registered', 'casual'].agg(['mean']).unstack(1).plot.bar(color = ['#d14233','#0048ba','#fa747d','#26ade4'])
plt.title('Registered and Casual Users at different weather conditions and days', color='black', size = 20)
plt.ylabel('Mean Number of users')
plt.legend(title='Users',labels= ['Registered Workfree','Registered Workingday','Casual Workfree', 'Casual Workingday'], loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# /var/folders/zs/dkf6mjq97k926d6m48gdwfs00000gn/T/ipykernel_39093/1251799811.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['weather', 'workingday'])['registered', 'casual'].agg(['mean']).unstack(1).plot.bar(color = ['#d14233','#0048ba','#fa747d','#26ade4'])

# %% [markdown]
# ### Registered and Casual Users at different weather conditions and days
# - work free means either weekend or holiday
# - in general more registered users compared to casual users
# - registered users use the bike mostly at workingdays (blue) and less on workfree days (red)
# - casual users use the bike more on workfree days (red) and less on workingdays (blue)
# - general decrese in usage for all users with bad weather conditions (weather 4 just happended once)

# %%
df_melted = df.melt(id_vars = ['weather', 'workingday'],# column names from original dataframe
                   value_vars=['casual', 'registered'], # from the original dataframe
                   var_name= 'users', # new column name for the variable column
                   value_name = 'num_users')

# %%
plt.figure(figsize = (10,6))
ax = sns.barplot(data=df_melted, y='num_users', x='users', hue = 'workingday')
plt.ylabel('Number of Users')
plt.xlabel('Bike Users')
#plt.legend(loc=(1.05, 1));
h, l = ax.get_legend_handles_labels()
ax.legend(h, ['weekend', 'work'], title='work or weekend')
plt.show()
#sns.despine()

# %%
plt.figure(figsize = (10,6))
ax = sns.boxplot(data=df_melted, y='num_users', x='users', hue = 'workingday')
plt.ylabel('Number of Users')
plt.xlabel('Bike Users')
h, l = ax.get_legend_handles_labels()
ax.legend(h, ['weekend', 'work'], title='work or weekend')
#sns.despine()

# %%
plt.figure(figsize = (10,6))
ax = sns.barplot(data=df_melted, y='num_users', x='users', hue = 'weather')
plt.ylabel('Number of Users')
plt.xlabel('Bike Users')
#plt.legend(title = 'weather', loc=(1.05, 1));
h, l = ax.get_legend_handles_labels()
ax.legend(h, ['Clear', 'Mist & Cloudy', 'Light Rain & Snow', 'Heavy Rain & Ice Pallets'], title='Weather Conditions')
sns.despine()

# %%
df.groupby(['weather'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='weather'>

# %%
df_2011.groupby(['weather'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='weather'>

# %%
df_2011['weather'].value_counts()
# Out:
# 1    3583
# 2    1366
# 3     473
# Name: weather, dtype: int64

# %%
df_2012['weather'].value_counts()
# Out:
# 1    3609
# 2    1468
# 3     386
# 4       1
# Name: weather, dtype: int64

# %%
df_2012[(df['weather']==4)]
# Out:
# /var/folders/zs/dkf6mjq97k926d6m48gdwfs00000gn/T/ipykernel_39093/4191102348.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2012[(df['weather']==4)]
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2012-01-09 18:00:00       1        0           1        4   8.2  11.365
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2012-01-09 18:00:00        86     6.0032       6         158    164  2012
#
#                      month  hour
# datetime
# 2012-01-09 18:00:00      1    18

# %%
df_2012.groupby(['weather'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='weather'>

# %%
df.groupby(['month'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='month'>

# %%
df.groupby(['year'])['count'].agg(['mean'])
# Out:
#             mean
# year
# 2011  144.223349
# 2012  238.560944

# %%
df_2011 = df[df['year']==2011]
df_2011.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16  2011
# 2011-01-01 01:00:00        80        0.0       8          32     40  2011
# 2011-01-01 02:00:00        80        0.0       5          27     32  2011
# 2011-01-01 03:00:00        75        0.0       3          10     13  2011
# 2011-01-01 04:00:00        75        0.0       0           1      1  2011
#
#                      month  hour
# datetime
# 2011-01-01 00:00:00      1     0
# 2011-01-01 01:00:00      1     1
# 2011-01-01 02:00:00      1     2
# 2011-01-01 03:00:00      1     3
# 2011-01-01 04:00:00      1     4

# %%
df_2012 = df[df['year']==2012]
df_2012.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-01-01 00:00:00       1        0           0        1  14.76  18.940
# 2012-01-01 01:00:00       1        0           0        1  14.76  17.425
# 2012-01-01 02:00:00       1        0           0        1  13.12  17.425
# 2012-01-01 03:00:00       1        0           0        1  12.30  16.665
# 2012-01-01 04:00:00       1        0           0        1  11.48  15.150
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2012-01-01 00:00:00        66     0.0000       5          43     48  2012
# 2012-01-01 01:00:00        66     8.9981      15          78     93  2012
# 2012-01-01 02:00:00        76     0.0000      16          59     75  2012
# 2012-01-01 03:00:00        81     0.0000      11          41     52  2012
# 2012-01-01 04:00:00        81     6.0032       0           8      8  2012
#
#                      month  hour
# datetime
# 2012-01-01 00:00:00      1     0
# 2012-01-01 01:00:00      1     1
# 2012-01-01 02:00:00      1     2
# 2012-01-01 03:00:00      1     3
# 2012-01-01 04:00:00      1     4

# %%
# comparing the months of year 2011
df_2011.groupby(['month'])['count'].agg(['mean'])
# Out:
#              mean
# month
# 1       54.645012
# 2       73.641256
# 3       86.849776
# 4      111.026374
# 5      174.809211
# 6      196.877193
# 7      203.614035
# 8      182.666667
# 9      174.622517
# 10     174.773626
# 11     155.458333
# 12     134.173246

# %%
# comparing the months of year 2011
df_2011.groupby(['month'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='month'>

# %%
# comparing the months of year 2012
df_2012.groupby(['month'])['count'].agg(['mean'])
# Out:
#              mean
# month
# 1      124.353201
# 2      145.646154
# 3      208.276923
# 4      257.455947
# 5      264.109649
# 6      287.186404
# 7      267.037281
# 8      285.570175
# 9      292.598684
# 10     280.508772
# 11     231.980220
# 12     217.054825

# %%
# comparing the months of year 2012
df_2012.groupby(['month'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='month'>

# %%
# comparing the two years
df.groupby(['year'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df.groupby(['hour'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
df_2011.groupby(['hour'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
df_2012.groupby(['hour'])['count'].agg(['mean']).plot.bar()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
df_2012.groupby(['hour'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df_2011[['registered', 'casual']].resample('30D').mean(), markers=True)

plt.xticks(rotation=15)
plt.ylabel('users')
plt.xlabel('datetime')

plt.title('registerd vs casual users 2011')

plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df_2012[['registered', 'casual']].resample('30D').mean(), markers=True)

plt.xticks(rotation=15)
plt.ylabel('users')
plt.xlabel('datetime')

plt.title('registerd vs casual users 2012')

plt.show()

# %%
# probably better to call it workfree because it is all weekend days and holidays
weekend = df[df['workingday'] == 0]
weekend.shape
# Out:
# (3474, 14)

# %%
# only weekend days without holidays
weekend_ohne_hol = df[(df['workingday'] == 0) & (df['holiday'] == 0)]
weekend_ohne_hol.shape
# Out:
# (3163, 14)

# %%
workday = df[df['workingday'] == 1]
workday.shape
# Out:
# (7412, 14)

# %%
# only holidays
holiday = df[(df['workingday'] == 0) & (df['holiday'] == 1)]
holiday.shape
# Out:
# (311, 14)

# %%
weekend.groupby(['hour'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
workday.groupby(['hour'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='hour'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=workday[['registered', 'casual']].resample('30D').mean(), markers=True)

plt.xticks(rotation=15)
plt.ylabel('users')
plt.xlabel('datetime')

plt.title('registerd vs casual users for work days')

plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=weekend[['registered', 'casual']].resample('30D').mean(), markers=True)

plt.xticks(rotation=15)
plt.ylabel('users')
plt.xlabel('datetime')

plt.title('registerd vs casual users for weekend')

plt.show()

# %%
sns.pairplot(
    df,
    x_vars=['atemp', 'workingday', 'count'],
    y_vars=['atemp', 'workingday', 'count'],
)

# %%
plt.figure(figsize=(6,6),dpi=100)
sns.heatmap(
    data=df[['atemp','humidity','windspeed','count', 'season', 'weather']].corr(),
    cmap='coolwarm',
    linecolor='white',
    linewidth=1,
    annot=True,
    vmin=-1,
    vmax=1
);

# %%
sns.lineplot(data=df, x='hour', y='count', hue='workingday')
# Out:
# <AxesSubplot: xlabel='hour', ylabel='count'>

# %%
df.groupby(['atemp'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='atemp'>

# %%
sns.lineplot(data=df, x='atemp', y='count', hue='workingday')
# Out:
# <AxesSubplot: xlabel='atemp', ylabel='count'>

# %%
df.groupby(['humidity'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='humidity'>

# %%
df.groupby(['windspeed'])['count'].agg(['mean']).plot.line()
# Out:
# <AxesSubplot: xlabel='windspeed'>

# %%
sns.scatterplot(data=df, x='temp', y='count')
# Out:
# <AxesSubplot: xlabel='temp', ylabel='count'>

# %%
sns.barplot(data=df, x='weather', y='count', hue='workingday')
# Out:
# <AxesSubplot: xlabel='weather', ylabel='count'>

# %%
sns.barplot(data=df, x='weather', y='casual', hue='workingday')
# Out:
# <AxesSubplot: xlabel='weather', ylabel='casual'>

# %%
sns.barplot(data=df, x='weather', y='registered', hue='workingday')
# Out:
# <AxesSubplot: xlabel='weather', ylabel='registered'>

# %%
sns.barplot(data=df_2012, x='weather', y='registered', hue='workingday')
# Out:
# <AxesSubplot: xlabel='weather', ylabel='registered'>

# %%
df.groupby(['casual', 'registered']).agg(['mean'])
# Out:
#                      season   holiday workingday   weather       temp  \
#                        mean      mean       mean      mean       mean
# casual registered
# 0      1           1.458333  0.010417   0.791667  1.520833  10.719792
#        2           1.843137  0.009804   0.823529  1.549020  12.943137
#        3           1.981818  0.027273   0.827273  1.581818  13.940000
#        4           2.177778  0.011111   0.855556  1.455556  14.942222
#        5           2.466667  0.011111   0.788889  1.544444  16.226889
# ...                     ...       ...        ...       ...        ...
# 356    316         2.000000  0.000000   0.000000  1.000000  29.520000
# 357    322         1.000000  0.000000   0.000000  1.000000  26.240000
# 361    369         2.000000  0.000000   0.000000  1.000000  29.520000
# 362    381         4.000000  0.000000   0.000000  1.000000  28.700000
# 367    318         1.000000  0.000000   0.000000  1.000000  26.240000
#
#                        atemp   humidity  windspeed  count         year  \
#                         mean       mean       mean   mean         mean
# casual registered
# 0      1           13.170938  65.072917  13.812957    1.0  2011.312500
#        2           15.775441  68.068627  12.362879    2.0  2011.431373
#        3           17.003955  71.218182  10.754779    3.0  2011.400000
#        4           18.072500  73.677778   9.800537    4.0  2011.411111
#        5           19.377056  70.388889  11.844856    5.0  2011.533333
# ...                      ...        ...        ...    ...          ...
# 356    316         32.575000  30.000000   7.001500  672.0  2012.000000
# 357    322         31.060000  53.000000   8.998100  679.0  2012.000000
# 361    369         32.575000  30.000000   6.003200  730.0  2012.000000
# 362    381         32.575000  54.000000   7.001500  743.0  2012.000000
# 367    318         31.060000  50.000000   0.000000  685.0  2012.000000
#
#                        month       hour
#                         mean       mean
# casual registered
# 0      1            3.260417   3.541667
#        2            4.460784   3.235294
#        3            4.936364   3.418182
#        4            5.566667   3.177778
#        5            6.144444   3.277778
# ...                      ...        ...
# 356    316          5.000000  15.000000
# 357    322          3.000000  15.000000
# 361    369          5.000000  14.000000
# 362    381         10.000000  12.000000
# 367    318          3.000000  16.000000
#
# [7263 rows x 12 columns]

# %%
df.resample('W').sum().plot();
# Out:
# /var/folders/zs/dkf6mjq97k926d6m48gdwfs00000gn/T/ipykernel_39093/4090581772.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.resample('W').sum().plot();

# %%
df['count'].resample('W').sum().plot();

# %%
df['atemp'].resample('W').sum().plot();

# %%
df['count'].resample('M').sum().plot();

# %%
df['atemp'].resample('M').sum().plot();

# %%
df['count'].resample('D').sum().rolling(30).sum().plot();

# %% [markdown]
# ### Plotting ideas:
# - influence of Temperature on bike rental
# - change weekend to workfree (only holiday not so important)
# - influence of humidity on bike rental

# %% [markdown]
# # 5. Feature Engineer

# %% [markdown]
# Features: X = df[['workingday', 'atemp', 'year', 'month', 'hour']]\
# Target: y = df['count']
#
# - workingday - kann so bleiben\
# - atemp - scaling with MinMaxScaler\
# - year - cat feature - onehot?\
# - month - cat feature - onehot?\
# - hour - binning ---> **ich will noch eigene Edges machen. Wenn es mit KBins nicht geht, dann mit pdcut funktion**
#     - Binning of day time; 22-5, 5-10, 10-16, 16-19, 19-22
# - humidity würde ich evtl nochihinzufügen\

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
X.head()
# Out:
#                      workingday   atemp  year  month  hour  humidity  weather  \
# datetime
# 2011-01-01 00:00:00           0  14.395  2011      1     0        81        1
# 2011-01-01 01:00:00           0  13.635  2011      1     1        80        1
# 2011-01-01 02:00:00           0  13.635  2011      1     2        80        1
# 2011-01-01 03:00:00           0  14.395  2011      1     3        75        1
# 2011-01-01 04:00:00           0  14.395  2011      1     4        75        1
#
#                      season
# datetime
# 2011-01-01 00:00:00       1
# 2011-01-01 01:00:00       1
# 2011-01-01 02:00:00       1
# 2011-01-01 03:00:00       1
# 2011-01-01 04:00:00       1

# %%
# differentiate between numerical and categorical features and columns which I want to bin
numerical_features = ['atemp', 'humidity']
categorical_features = ['year', 'month', 'weather', 'season']
binning_features = ['hour']

# %%
# column transformation
transformer = ColumnTransformer([
    ('scaling', MinMaxScaler(), numerical_features),
    ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_features), #habe drop='first' weggenommen
    ('binning', KBinsDiscretizer(n_bins=24, encode='onehot', strategy='uniform'), binning_features)],
    remainder = 'passthrough'
)

# %% [markdown]
# # column transformation with out binning (hours binned with pd.cut)
# transformer = ColumnTransformer([
#     ('scaling', MinMaxScaler(), numerical_features),
#     ('onehot', OneHotEncoder(drop='first'), categorical_features)],
#     remainder = 'passthrough'
# )

# %%
# pipeline
pipeline = Pipeline(
    [('col_transformer', transformer),                  # step-1 column transformation
     ('lr_model', LinearRegression(fit_intercept=True)) # step-2 linear fit
    ])

# %%
# model training if I use pipline as in linear_regression notebook from 20th Dec. 
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scaling', MinMaxScaler(),
#                                                   ['atemp', 'humidity']),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['year', 'month', 'weather',
#                                                    'season']),
#                                                  ('binning',
#                                                   KBinsDiscretizer(n_bins=24,
#                                                                    strategy='uniform'),
#                                                   ['hour'])])),
#                 ('lr_model', LinearRegression())])

# %%
transformer.fit(X_train)
X_train_fe = transformer.transform(X_train)
X_test_fe = transformer.transform(X_test) # DO NOT FIT ON TEST SET

# %% [markdown]
# # 6. Train model

# %% [markdown]
# Linear Regression, Poisson or RandomForestRegressor

# %% [markdown]
# ## 6. a) Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# train model
LinReg = LinearRegression() #create a model
LinReg.fit(X_train_fe,y_train) #train the model
# Out:
# LinearRegression()

# %%
LinReg.score(X_train_fe,y_train)
# Out:
# 0.6984627622903461

# %%
LinReg.score(X_test_fe, y_test)
# Out:
# 0.6683600881656196

# %% [markdown]
# #### Model Evaluation with pipline

# %%
# training score if I use pipline as in the linear_regression notebook from the 20th of Dec otherwise LingReg.score as above

training_score = pipeline.score(X_train,y_train)
print(f'training score: {round(training_score,6)}')
# Out:
# training score: 0.698463

# %%
# test score
test_score = pipeline.score(X_test,y_test)
print(f'test score: {round(test_score,6)}')
# Out:
# test score: 0.66836

# %% [markdown]
# ### 6.aa) Feature Expansion / Regularization

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## 6.b) RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

rfr = RandomForestRegressor(n_estimators = 100, random_state=0)

# %%
rfr.fit(X_train_fe, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
rfr.score(X_train_fe, y_train)
# Out:
# 0.9883237999109821

# %%
rfr.score(X_test_fe, y_test)
# Out:
# 0.9120927450203002

# %% [markdown]
# ## 6.c) Poisson Regression

# %%
from sklearn.linear_model import PoissonRegressor
pr = PoissonRegressor()
pr.fit(X_train_fe, y_train)
# Out:
# PoissonRegressor()

# %%
pr.score(X_train_fe, y_train)
# Out:
# 0.7791147849615921

# %%
pr.score(X_test_fe, y_test)
# Out:
# 0.7565944119198649

# %% [markdown]
# ## Submission for Kaggel

# %%
df_test = pd.read_csv('data/test.csv')
df_test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# extract year, month and hour
df_test['year'] = pd.DatetimeIndex(df_test['datetime']).year
df_test['month'] = pd.DatetimeIndex(df_test['datetime']).month
df_test['hour'] = pd.DatetimeIndex(df_test['datetime']).hour
df_test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  hour
# 0        56    26.0027  2011      1     0
# 1        56     0.0000  2011      1     1
# 2        56     0.0000  2011      1     2
# 3        56    11.0014  2011      1     3
# 4        56    11.0014  2011      1     4

# %%
# set datetime as index
df_test.set_index(pd.to_datetime(df_test['datetime']), inplace= True)
df_test.head()
# Out:
#                                 datetime  season  holiday  workingday  \
# datetime
# 2011-01-20 00:00:00  2011-01-20 00:00:00       1        0           1
# 2011-01-20 01:00:00  2011-01-20 01:00:00       1        0           1
# 2011-01-20 02:00:00  2011-01-20 02:00:00       1        0           1
# 2011-01-20 03:00:00  2011-01-20 03:00:00       1        0           1
# 2011-01-20 04:00:00  2011-01-20 04:00:00       1        0           1
#
#                      weather   temp   atemp  humidity  windspeed  year  month  \
# datetime
# 2011-01-20 00:00:00        1  10.66  11.365        56    26.0027  2011      1
# 2011-01-20 01:00:00        1  10.66  13.635        56     0.0000  2011      1
# 2011-01-20 02:00:00        1  10.66  13.635        56     0.0000  2011      1
# 2011-01-20 03:00:00        1  10.66  12.880        56    11.0014  2011      1
# 2011-01-20 04:00:00        1  10.66  12.880        56    11.0014  2011      1
#
#                      hour
# datetime
# 2011-01-20 00:00:00     0
# 2011-01-20 01:00:00     1
# 2011-01-20 02:00:00     2
# 2011-01-20 03:00:00     3
# 2011-01-20 04:00:00     4

# %%
# remove unnecessary column
df_test.drop(['datetime'], axis = 1, inplace= True)
df_test.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed  year  month  hour
# datetime
# 2011-01-20 00:00:00        56    26.0027  2011      1     0
# 2011-01-20 01:00:00        56     0.0000  2011      1     1
# 2011-01-20 02:00:00        56     0.0000  2011      1     2
# 2011-01-20 03:00:00        56    11.0014  2011      1     3
# 2011-01-20 04:00:00        56    11.0014  2011      1     4

# %%
df_test['hour_bins']=pd.cut(df_test['hour'], bins=[-1,6,9,15,19,23], labels =['night','morgning-rush','midday-low','afterwork-rush','evening-low'])
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16  2011
# 2011-01-01 01:00:00        80        0.0       8          32     40  2011
# 2011-01-01 02:00:00        80        0.0       5          27     32  2011
# 2011-01-01 03:00:00        75        0.0       3          10     13  2011
# 2011-01-01 04:00:00        75        0.0       0           1      1  2011
#
#                      month  hour hour_bins
# datetime
# 2011-01-01 00:00:00      1     0     night
# 2011-01-01 01:00:00      1     1     night
# 2011-01-01 02:00:00      1     2     night
# 2011-01-01 03:00:00      1     3     night
# 2011-01-01 04:00:00      1     4     night

# %%
test = df_test[['workingday', 'atemp', 'year', 'month','hour','humidity', 'weather', 'season']]
test.head()
# Out:
#                      workingday   atemp  year  month  hour  humidity  weather  \
# datetime
# 2011-01-20 00:00:00           1  11.365  2011      1     0        56        1
# 2011-01-20 01:00:00           1  13.635  2011      1     1        56        1
# 2011-01-20 02:00:00           1  13.635  2011      1     2        56        1
# 2011-01-20 03:00:00           1  12.880  2011      1     3        56        1
# 2011-01-20 04:00:00           1  12.880  2011      1     4        56        1
#
#                      season
# datetime
# 2011-01-20 00:00:00       1
# 2011-01-20 01:00:00       1
# 2011-01-20 02:00:00       1
# 2011-01-20 03:00:00       1
# 2011-01-20 04:00:00       1

# %%
test_fe = transformer.transform(test)

# %%
#predictions from RandomForestRegressor
predictions = rfr.predict(test_fe)
output = pd.DataFrame({'datetime': df_test.index, 'count': predictions})
output.to_csv('submission_rfr_6.csv', index=False)

# %%
#predictions from RandomForestRegressor
predictions_pr = pr.predict(test_fe)
output = pd.DataFrame({'datetime': df_test.index, 'count': predictions_pr})
output.to_csv('submission_pr_1.csv', index=False)
